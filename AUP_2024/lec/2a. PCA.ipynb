# %% [markdown]
# # Principal Component Analysis (PCA)
#
# This notebook provides the code for the Part 2 of the Exploratory Data Analysis course.  Please review in conjunction with the course notes.

# %% [markdown]
# ## Carry out a PCA
#
# ### Import libraries
# Import the libraries we need.

# %%
# Import standard libraries
import pandas as pd
import numpy as np

# Import functions created for this course
from functions import *

# %% [markdown]
# ### Loading and cleaning data
# Load the data from the csv file:

# %%
# Load the data from the csv file into a Pandas Dataframe
original_data = pd.read_csv('world_university_rankings_2016.csv', index_col='university_name')
original_data.head()
# Out:
#                                        world_rank                   country  \
# university_name
# California Institute of Technology              1  United States of America
# University of Oxford                            2            United Kingdom
# Stanford University                             3  United States of America
# University of Cambridge                         4            United Kingdom
# Massachusetts Institute of Technology           5  United States of America
#
#                                        teaching  international  research  \
# university_name
# California Institute of Technology         95.6           64.0      97.6
# University of Oxford                       86.5           94.4      98.9
# Stanford University                        92.5           76.3      96.2
# University of Cambridge                    88.2           91.5      96.7
# Massachusetts Institute of Technology      89.4           84.0      88.6
#
#                                        citations  income  total_score  \
# university_name
# California Institute of Technology          99.8    97.8         95.2
# University of Oxford                        98.8    73.1         94.2
# Stanford University                         99.9    63.3         93.9
# University of Cambridge                     97.0    55.0         92.8
# Massachusetts Institute of Technology       99.7    95.4         92.0
#
#                                        num_students  student_staff_ratio  \
# university_name
# California Institute of Technology           2243.0                  6.9
# University of Oxford                        19919.0                 11.6
# Stanford University                         15596.0                  7.8
# University of Cambridge                     18812.0                 11.8
# Massachusetts Institute of Technology       11074.0                  9.0
#
#                                        international%  female%  male%
# university_name
# California Institute of Technology               27.0     33.0   67.0
# University of Oxford                             34.0     46.0   54.0
# Stanford University                              22.0     42.0   58.0
# University of Cambridge                          34.0     46.0   54.0
# Massachusetts Institute of Technology            33.0     37.0   63.0

# %% [markdown]
# Filter our data down to just the remaining columns of interest:

# %%
X = original_data[['teaching', 'international', 'research', 
       'citations', 'income', 'num_students', 'student_staff_ratio', 
       'international%', 'female%','male%']]
X.head()
# Out:
#                                        teaching  international  research  \
# university_name
# California Institute of Technology         95.6           64.0      97.6
# University of Oxford                       86.5           94.4      98.9
# Stanford University                        92.5           76.3      96.2
# University of Cambridge                    88.2           91.5      96.7
# Massachusetts Institute of Technology      89.4           84.0      88.6
#
#                                        citations  income  num_students  \
# university_name
# California Institute of Technology          99.8    97.8        2243.0
# University of Oxford                        98.8    73.1       19919.0
# Stanford University                         99.9    63.3       15596.0
# University of Cambridge                     97.0    55.0       18812.0
# Massachusetts Institute of Technology       99.7    95.4       11074.0
#
#                                        student_staff_ratio  international%  \
# university_name
# California Institute of Technology                     6.9            27.0
# University of Oxford                                  11.6            34.0
# Stanford University                                    7.8            22.0
# University of Cambridge                               11.8            34.0
# Massachusetts Institute of Technology                  9.0            33.0
#
#                                        female%  male%
# university_name
# California Institute of Technology        33.0   67.0
# University of Oxford                      46.0   54.0
# Stanford University                       42.0   58.0
# University of Cambridge                   46.0   54.0
# Massachusetts Institute of Technology     37.0   63.0

# %% [markdown]
# See if our data contains nulls:

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 800 entries, California Institute of Technology to Yuan Ze University
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   teaching             800 non-null    float64
#  1   international        800 non-null    float64
#  2   research             800 non-null    float64
#  3   citations            800 non-null    float64
#  4   income               763 non-null    float64
#  5   num_students         793 non-null    float64
#  6   student_staff_ratio  793 non-null    float64
#  7   international%       790 non-null    float64
#  8   female%              736 non-null    float64
#  9   male%                736 non-null    float64
# dtypes: float64(10)
# memory usage: 68.8+ KB

# %% [markdown]
# Replace nulls with the mean value for the variable.

# %%
X = X.fillna(X.mean())

# %% [markdown]
# ### Standardising the data
# Check the range of values for the variables we have.

# %%
X.describe()
# Out:
#        teaching  international    research  citations      income  \
# count  800.0000     800.000000  800.000000  800.00000  800.000000
# mean    31.5840      48.500375   28.128625   51.30975   46.869594
# std     14.9854      23.690816   19.532270   27.04544   20.094099
# min      9.9000       7.100000    2.900000    1.20000   28.000000
# 25%     21.0000      29.450000   14.350000   27.52500   31.800000
# 50%     27.0000      45.700000   22.100000   50.30000   39.900000
# 75%     37.5000      65.450000   35.525000   74.90000   53.700000
# max     95.6000      99.900000   99.000000  100.00000  100.000000
#
#         num_students  student_staff_ratio  international%     female%  \
# count     800.000000           800.000000      800.000000  800.000000
# mean    24161.264817            19.116393       12.702532   49.538043
# std     22470.143414            12.467030       10.609056   11.473152
# min       462.000000             0.600000        0.000000    1.000000
# 25%     12344.000000            12.300000        5.000000   46.000000
# 50%     20307.000000            16.850000       10.000000   51.000000
# 75%     29640.500000            22.225000       18.000000   56.000000
# max    379231.000000           162.600000       82.000000  100.000000
#
#             male%
# count  800.000000
# mean    50.461957
# std     11.473152
# min      0.000000
# 25%     44.000000
# 50%     49.000000
# 75%     54.000000
# max     99.000000

# %% [markdown]
# Apply the standard scaler:

# %%
# Import the sklearn function
from sklearn.preprocessing import StandardScaler

# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled
# Out:
# array([[ 4.27456366,  0.65465542,  3.55897378, ...,  1.34850955,
#         -1.44235777,  1.44235777],
#        [ 3.66692605,  1.93865583,  3.62557194, ...,  2.008736  ,
#         -0.30856882,  0.30856882],
#        [ 4.06756624,  1.17416874,  3.48725268, ...,  0.87691922,
#         -0.65742695,  0.65742695],
#        ...,
#        [-0.50640919, -1.36848995, -0.91847191, ..., -0.91512401,
#          0.        ,  0.        ],
#        [-0.76682531, -1.0643846 , -0.62134164, ..., -0.44353369,
#         -1.87843044,  1.87843044],
#        [-1.02724143, -1.30091099, -0.50351413, ..., -0.82080595,
#         -0.57021242,  0.57021242]])

# %% [markdown]
# Plot the data before scaling:

# %%
X1 = pd.DataFrame(X,columns=X.columns)
X1.drop('num_students', axis=1,inplace=True)
X1.plot(kind='density',sharex=True,figsize=(12,5),layout=(10,1))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
X1
# Out:
#                                        teaching  international  research  \
# university_name
# California Institute of Technology         95.6           64.0      97.6
# University of Oxford                       86.5           94.4      98.9
# Stanford University                        92.5           76.3      96.2
# University of Cambridge                    88.2           91.5      96.7
# Massachusetts Institute of Technology      89.4           84.0      88.6
# ...                                         ...            ...       ...
# Yeungnam University                        18.6           24.3      10.9
# Yıldız Technical University                14.5           14.9       7.6
# Yokohama City University                   24.0           16.1      10.2
# Yokohama National University               20.1           23.3      16.0
# Yuan Ze University                         16.2           17.7      18.3
#
#                                        citations  income  student_staff_ratio  \
# university_name
# California Institute of Technology          99.8    97.8                  6.9
# University of Oxford                        98.8    73.1                 11.6
# Stanford University                         99.9    63.3                  7.8
# University of Cambridge                     97.0    55.0                 11.8
# Massachusetts Institute of Technology       99.7    95.4                  9.0
# ...                                          ...     ...                  ...
# Yeungnam University                         26.5    35.4                 15.3
# Yıldız Technical University                 19.3    44.0                 28.7
# Yokohama City University                    36.4    37.9                  3.7
# Yokohama National University                13.5    40.4                 12.1
# Yuan Ze University                          28.6    39.8                 20.6
#
#                                        international%    female%      male%
# university_name
# California Institute of Technology               27.0  33.000000  67.000000
# University of Oxford                             34.0  46.000000  54.000000
# Stanford University                              22.0  42.000000  58.000000
# University of Cambridge                          34.0  46.000000  54.000000
# Massachusetts Institute of Technology            33.0  37.000000  63.000000
# ...                                               ...        ...        ...
# Yeungnam University                               3.0  48.000000  52.000000
# Yıldız Technical University                       2.0  36.000000  64.000000
# Yokohama City University                          3.0  49.538043  50.461957
# Yokohama National University                      8.0  28.000000  72.000000
# Yuan Ze University                                4.0  43.000000  57.000000
#
# [800 rows x 9 columns]

# %% [markdown]
# The distribution for max_students is on such a different scale that we need to plot it separately:

# %%
X2 = pd.DataFrame(X,columns=X.columns)['num_students']
X2.plot(kind='density',sharex=True,figsize=(12,5),layout=(10,1))
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# Plot the data after standarisation:

# %%
pd.DataFrame(X_scaled,columns=X.columns).plot(kind='density',sharex=True,figsize=(12,5),layout=(10,1))
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ### Perform PCA
# Perform a PCA on our standardised data:

# %%
# Import the PCA function from sklearn
from sklearn.decomposition import PCA

# Select the number of principal components we will return
num_components = 10

# Create the PCA model
pca = PCA(n_components=num_components)

# Fit the model with the standardised data
pca.fit(X_scaled)
# Out:
# PCA(n_components=10)

# %% [markdown]
# ## Analyse the results

# %% [markdown]
# ### Explained Variance Ratio
# Array of the variance of the data explained by each of the 10 principal components, starting with PC1, the principal component that explains most of the variance.

# %%
pca.explained_variance_ratio_
# Out:
# array([3.21371891e-01, 2.37089839e-01, 1.55600315e-01, 1.05351043e-01,
#        6.92858779e-02, 5.47049848e-02, 3.52056608e-02, 1.45935070e-02,
#        6.79688170e-03, 4.04436782e-33])

# %% [markdown]
# Express the explained variance ratio as a cumulative sum:

# %%
pca.explained_variance_ratio_.cumsum()
# Out:
# array([0.32137189, 0.55846173, 0.71406204, 0.81941309, 0.88869897,
#        0.94340395, 0.97860961, 0.99320312, 1.        , 1.        ])

# %% [markdown]
# ### Scree Plot
# The explained variance ratio in a **scree plot**.

# %%
display_scree_plot(pca)

# %% [markdown]
# ### Component Scores
# Get the components from the pca object:

# %%
pc1 = pca.components_[0]
pc2 = pca.components_[1]
pc3 = pca.components_[2]
# etc

# %% [markdown]
# Remind ourselves of what columns we have in the data:

# %%
X.columns
# Out:
# Index(['teaching', 'international', 'research', 'citations', 'income',
#        'num_students', 'student_staff_ratio', 'international%', 'female%',
#        'male%'],
#       dtype='object')

# %% [markdown]
# Look at the components:

# %%
pc1
# Out:
# array([ 0.44602246,  0.41763286,  0.47918623,  0.4372045 ,  0.17746079,
#        -0.06111775, -0.0565289 ,  0.39562507,  0.07394972, -0.07394972])

# %% [markdown]
# Do the same for PC2:

# %%
pc2 = pca.components_[1]
pc2
# Out:
# array([-0.17388542,  0.17493695, -0.14625   ,  0.0530956 , -0.28297188,
#         0.2070367 ,  0.21899687,  0.09335706,  0.60635809, -0.60635809])

# %% [markdown]
# ### Correlation Circle
#
# Plot these component scores on a correlation circle - PC1 against PC2:

# %%
# Generate a correlation circle
pcs = pca.components_ 
display_circles(pcs, num_components, pca, [(0,1)], labels = np.array(X.columns),)

# %% [markdown]
# PC2 against PC3:

# %%
# Generate a correlation circle
pcs = pca.components_ 
display_circles(pcs, num_components, pca, [(1,2)], labels = np.array(X.columns),)

# %% [markdown]
# ### Individuals Factor Map
# Plot our samples on a scatter plot in the new factorial planes.

# %%
# Transform the original scaled data to the new vector space
X_projected = pca.transform(X_scaled) 

# Display a scatter plot of the data points in this new vector space
display_factorial_planes(X_projected, num_components, pca, [(0,1)])
plt.show()

# %% [markdown]
# Band the data into the top 10, top 100 and top 1000 universities:

# %%
# Take a copy of the data an add a new column for the banding
classed_data = original_data.copy()
append_class(classed_data, 'rank_band','world_rank',[0,11,101,1000],['10','100','1000'])

# Get a list of the new bandings that we can pass to the plot
classed_data = classed_data.reset_index()
rank_band = [classed_data.loc[uni_id, "rank_band"] for uni_id in range(0,len(X_scaled))]

# %% [markdown]
# Plot the samples again, this time showing the bands as separate colours:

# %%
# Transform the original scaled data to the new vector space and display data points
X_projected = pca.transform(X_scaled)
display_factorial_planes(X_projected, num_components, pca, [(0,1)], illustrative_var = rank_band, alpha = 0.5)

# %% [markdown]
# Factor maps for other factorial planes:

# %%
X_projected = pca.transform(X_scaled)
display_factorial_planes(X_projected, num_components, pca, [(1,2),(2,3),(3,4)], illustrative_var = rank_band, alpha = 0.5)
