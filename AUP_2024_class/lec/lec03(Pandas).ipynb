# %% [markdown]
# # Pandas, groupby and filtering data

# %%
import pandas as pd
# Out:
# /home/tdejaege/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/tdejaege/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# initialize list of lists
data = [['Tom', 10], ['Nick', 15], ['Julie', 14]]
 
# Create the pandas DataFrame
df = pd.DataFrame(data, columns=['Name', 'Age'])
 
# print dataframe.
print(df)
# Out:
#     Name  Age
# 0    Tom   10
# 1   Nick   15
# 2  Julie   14

# %%
 
# Initialize data to lists.
# initialize data of lists.
data = {'Name': ['Tom', 'Nick', 'Julie'],
        'Age': [10, 15, 14]}
 
# Create DataFrame
df = pd.DataFrame(data)
 
# Print the output.
print(df)
# Out:
#     Name  Age
# 0    Tom   10
# 1   Nick   15
# 2  Julie   14

# %% [markdown]
# ### Load the data: drinks

# %%
drinks = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv')

# %% [markdown]
# ### Data exploration

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
drinks.shape
# Out:
# (193, 6)

# %%
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     170 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
drinks.isnull()
# Out:
#      country  beer_servings  spirit_servings  wine_servings  \
# 0      False          False            False          False
# 1      False          False            False          False
# 2      False          False            False          False
# 3      False          False            False          False
# 4      False          False            False          False
# ..       ...            ...              ...            ...
# 188    False          False            False          False
# 189    False          False            False          False
# 190    False          False            False          False
# 191    False          False            False          False
# 192    False          False            False          False
#
#      total_litres_of_pure_alcohol  continent
# 0                           False      False
# 1                           False      False
# 2                           False      False
# 3                           False      False
# ...

# %%
for attribute in drinks.columns:
    
    null_check = pd.isnull(drinks[attribute])
    print(drinks[null_check])
# Out:
# Empty DataFrame
# Columns: [country, beer_servings, spirit_servings, wine_servings, total_litres_of_pure_alcohol, continent]
# Index: []
# Empty DataFrame
# Columns: [country, beer_servings, spirit_servings, wine_servings, total_litres_of_pure_alcohol, continent]
# Index: []
# Empty DataFrame
# Columns: [country, beer_servings, spirit_servings, wine_servings, total_litres_of_pure_alcohol, continent]
# Index: []
# Empty DataFrame
# Columns: [country, beer_servings, spirit_servings, wine_servings, total_litres_of_pure_alcohol, continent]
# Index: []
# Empty DataFrame
# Columns: [country, beer_servings, spirit_servings, wine_servings, total_litres_of_pure_alcohol, continent]
# Index: []
#                           country  beer_servings  spirit_servings  \
# 5               Antigua & Barbuda            102              128
# 11                        Bahamas            122              176
# 14                       Barbados            143              173
# ...

# %%
drinks["continent"].fillna('NorthAm', inplace=True)
drinks.continent.values
# Out:
# /tmp/ipykernel_2382498/428556126.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   drinks["continent"].fillna('NorthAm', inplace=True)
# array(['AS', 'EU', 'AF', 'EU', 'AF', 'NorthAm', 'SA', 'EU', 'OC', 'EU',
#        'EU', 'NorthAm', 'AS', 'AS', 'NorthAm', 'EU', 'EU', 'NorthAm',
#        'AF', 'AS', 'SA', 'EU', 'AF', 'SA', 'AS', 'EU', 'AF', 'AF', 'AF',
#        'AF', 'AS', 'AF', 'NorthAm', 'AF', 'AF', 'SA', 'AS', 'SA', 'AF',
#        'AF', 'OC', 'NorthAm', 'EU', 'NorthAm', 'EU', 'EU', 'AS', 'AF',
# ...

# %%
capitalizer = lambda x: x.upper()
drinks['country']=drinks['country'].apply(capitalizer)
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    AFGHANISTAN              0                0              0
# 1        ALBANIA             89              132             54
# 2        ALGERIA             25                0             14
# 3        ANDORRA            245              138            312
# 4         ANGOLA            217               57             45
# ..           ...            ...              ...            ...
# 188    VENEZUELA            333              100              3
# 189      VIETNAM            111                2              1
# 190        YEMEN              6                0              0
# 191       ZAMBIA             32               19              4
# 192     ZIMBABWE             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
def lower(country):
    return country.lower()
drinks['country']=drinks['country'].apply(lower)
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    afghanistan              0                0              0
# 1        albania             89              132             54
# 2        algeria             25                0             14
# 3        andorra            245              138            312
# 4         angola            217               57             45
# ..           ...            ...              ...            ...
# 188    venezuela            333              100              3
# 189      vietnam            111                2              1
# 190        yemen              6                0              0
# 191       zambia             32               19              4
# 192     zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
print(drinks.wine_servings.mean())
def over_wine_average(x):
    if x > drinks.wine_servings.mean():
        return True
    else:
        return False
drinks['over_wine_average'] = drinks['wine_servings'].apply(over_wine_average)   
drinks
# Out:
# 49.45077720207254
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    afghanistan              0                0              0
# 1        albania             89              132             54
# 2        algeria             25                0             14
# 3        andorra            245              138            312
# 4         angola            217               57             45
# ..           ...            ...              ...            ...
# 188    venezuela            333              100              3
# 189      vietnam            111                2              1
# 190        yemen              6                0              0
# 191       zambia             32               19              4
# 192     zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent  over_wine_average
# 0                             0.0        AS              False
# ...

# %% [markdown]
# ### Which continent drinks more beer on average?

# %%
drinks.groupby('continent').beer_servings.mean()
# Out:
# continent
# AF          61.471698
# AS          37.045455
# EU         193.777778
# NorthAm    145.434783
# OC          89.687500
# SA         175.083333
# Name: beer_servings, dtype: float64

# %% [markdown]
# ### Which country drinks more beer?

# %%
drinks.loc[drinks['beer_servings']==max(drinks['beer_servings'])]
# Out:
#      country  beer_servings  spirit_servings  wine_servings  \
# 117  namibia            376                3              1
#
#      total_litres_of_pure_alcohol continent  over_wine_average
# 117                           6.8        AF              False

# %% [markdown]
# ### For each continent print the statistics for wine consumption.

# %%
drinks.groupby('continent').wine_servings.describe()
# Out:
#            count        mean        std  min   25%    50%     75%    max
# continent
# AF          53.0   16.264151  38.846419  0.0   1.0    2.0   13.00  233.0
# AS          44.0    9.068182  21.667034  0.0   0.0    1.0    8.00  123.0
# EU          45.0  142.222222  97.421738  0.0  59.0  128.0  195.00  370.0
# NorthAm     23.0   24.521739  28.266378  1.0   5.0   11.0   34.00  100.0
# OC          16.0   35.625000  64.555790  0.0   1.0    8.5   23.25  212.0
# SA          12.0   62.416667  88.620189  1.0   3.0   12.0   98.50  221.0

# %% [markdown]
# ### Is France the country where we drink more wine?

# %%
drinks.sort_values(by=['wine_servings'],ascending=False)
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 61        france            127              151            370
# 136     portugal            194               67            339
# 3        andorra            245              138            312
# 166  switzerland            185              100            280
# 48       denmark            224               81            278
# ..           ...            ...              ...            ...
# 79          iran              0                0              0
# 161    sri lanka             16              104              0
# 128     pakistan              0                0              0
# 78     indonesia              5                1              0
# 0    afghanistan              0                0              0
#
#      total_litres_of_pure_alcohol continent  over_wine_average
# 61                           11.8        EU               True
# 136                          11.0        EU               True
# ...

# %% [markdown]
# ### And for the spirit?

# %%
drinks.sort_values(by=['spirit_servings'],ascending=False)
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 68              grenada            199              438             28
# 15              belarus            142              373             42
# 73                haiti              1              326              1
# 141  russian federation            247              326             73
# 144           st. lucia            171              315             71
# ..                  ...            ...              ...            ...
# 158             somalia              0                0              0
# 128            pakistan              0                0              0
# 63               gambia              8                0              1
# 56              eritrea             18                0              0
# 0           afghanistan              0                0              0
#
#      total_litres_of_pure_alcohol continent  over_wine_average
# ...

# %% [markdown]
# ### Print the european countries which do not drink any alcool

# %%
europe=drinks[drinks.continent=='EU']
europe
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 1               albania             89              132             54
# 3               andorra            245              138            312
# 7               armenia             21              179             11
# 9               austria            279               75            191
# 10           azerbaijan             21               46              5
# 15              belarus            142              373             42
# 16              belgium            295               84            212
# 21   bosnia-herzegovina             76              173              8
# 25             bulgaria            231              252             94
# 42              croatia            230               87            254
# 44               cyprus            192              154            113
# 45       czech republic            361              170            134
# ...

# %%
europe[europe.iloc[:, 1:4].sum(axis=1)==0]
# Out:
#         country  beer_servings  spirit_servings  wine_servings  \
# 111      monaco              0                0              0
# 147  san marino              0                0              0
#
#      total_litres_of_pure_alcohol continent  over_wine_average
# 111                           0.0        EU              False
# 147                           0.0        EU              False

# %%
drinks[(drinks.continent=='AF') & (drinks[drinks.continent=='AF'].iloc[:, 1:4].sum(axis=1)==0)]
# Out:
#         country  beer_servings  spirit_servings  wine_servings  \
# 97        libya              0                0              0
# 107  mauritania              0                0              0
# 158     somalia              0                0              0
#
#      total_litres_of_pure_alcohol continent  over_wine_average
# 97                            0.0        AF              False
# 107                           0.0        AF              False
# 158                           0.0        AF              False

# %%
countries=['Syria','Iraq','Saudi Arabia']
drinks.loc[drinks.country.isin(countries)]
# Out:
# Empty DataFrame
# Columns: [country, beer_servings, spirit_servings, wine_servings, total_litres_of_pure_alcohol, continent, over_wine_average]
# Index: []

# %% [markdown]
# ###  Print the mean alcohol consumption per continent for every column

# %%
drinks.groupby('continent').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1941         try:
# -> 1942             res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943         except Exception as err:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#     863
# --> 864         result = self._aggregate_series_pure_python(obj, func)
#     865
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#     884         for i, group in enumerate(splitter):
# --> 885             res = func(group)
#     886             res = extract_result(res)
#
# ...

# %% [markdown]
# ### Print the median alcohol consumption per continent for every column

# %%
drinks.groupby('continent').median()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1941         try:
# -> 1942             res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943         except Exception as err:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#     863
# --> 864         result = self._aggregate_series_pure_python(obj, func)
#     865
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#     884         for i, group in enumerate(splitter):
# --> 885             res = func(group)
#     886             res = extract_result(res)
#
# ...

# %% [markdown]
# ### Print the mean, min and max values for spirit consumption.
# #### This time output a DataFrame

# %%
drinks.groupby('continent').spirit_servings.agg(['mean', 'min', 'max'])
# Out:
#                  mean  min  max
# continent
# AF          16.339623    0  152
# AS          60.840909    0  326
# EU         132.555556    0  373
# NorthAm    165.739130   68  438
# OC          58.437500    0  254
# SA         114.750000   25  302

# %% [markdown]
# ### Look at all the countries starting with F.

# %%
drinks[drinks.country.str.startswith('f')]
# Out:
#     country  beer_servings  spirit_servings  wine_servings  \
# 59     fiji             77               35              1
# 60  finland            263              133             97
# 61   france            127              151            370
#
#     total_litres_of_pure_alcohol continent  over_wine_average
# 59                           2.0        OC              False
# 60                          10.0        EU               True
# 61                          11.8        EU               True

# %%
drinks.iloc[: , 0:2]
# Out:
#          country  beer_servings
# 0    afghanistan              0
# 1        albania             89
# 2        algeria             25
# 3        andorra            245
# 4         angola            217
# ..           ...            ...
# 188    venezuela            333
# 189      vietnam            111
# 190        yemen              6
# 191       zambia             32
# 192     zimbabwe             64
#
# [193 rows x 2 columns]

# %% [markdown]
# ### Correlation between wine, spirit, beer consumation?

# %% [markdown]
# We begin by plotting a correlation heatmap.
#
# In statistics, correlation refers to the statistical measure that quantifies the relationship between two or more variables.
#
# It helps us understand how changes in one variable are associated with changes in another variable.
#
# Correlation does not imply causation; it only shows the strength and direction of the linear relationship between the variables.
#
# There are different types of correlation coefficients that can be used to measure the correlation between variables, with the most common one being the **Pearson correlation coefficient**.
#
# The Pearson correlation coefficient, denoted by **"r"**, measures the linear relationship between two continuous variables.
#
# It ranges from -1 to +1:
#
# 1. A correlation coefficient of -1 indicates a perfect negative correlation, where the    variables move in opposite directions with a strong linear relationship.
#
# 2. A correlation coefficient of 0 indicates no linear relationship between the variables (they are uncorrelated).
#
# 3. A correlation coefficient of +1 indicates a perfect positive correlation, where the variables move in the same direction with a strong linear relationship.
#
# 1. 0 - 0.1 No Correlation
# 2. 0.1 - 0.3 Low Correlation
# 3. 0.3 - 0.5 Medium Correlation
# 4. 0.5 - 0.7 High Correlation
# 5. 0.7 - 1 Very High Correlation

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.figure(figsize = (10, 6))
sns.heatmap(drinks.corr(), annot = True, cmap = 'YlGnBu')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_2382498/2088461667.py in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 import seaborn as sns
#       3 get_ipython().run_line_magic('matplotlib', 'inline')
#       4 plt.figure(figsize = (10, 6))
#       5 sns.heatmap(drinks.corr(), annot = True, cmap = 'YlGnBu')
#
# ~/anaconda3/lib/python3.9/site-packages/seaborn/__init__.py in <module>
#       1 # Import seaborn objects
# ----> 2 from .rcmod import *  # noqa: F401,F403
#       3 from .utils import *  # noqa: F401,F403
#       4 from .palettes import *  # noqa: F401,F403
#       5 from .relational import *  # noqa: F401,F403
#
# ~/anaconda3/lib/python3.9/site-packages/seaborn/rcmod.py in <module>
#       5 import matplotlib as mpl
#       6 from cycler import cycler
# ----> 7 from . import palettes
#       8
#       9
#
# ...

# %%
drinks.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2382498/902806889.py in <module>
# ----> 1 drinks.corr()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1991         if dtype is not None:
#    1992             dtype = np.dtype(dtype)
# -> 1993         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994         if result.dtype is not dtype:
#    1995             result = np.asarray(result, dtype=dtype)
#
# ...

# %%
df.groupby("genre").agg(salaire_moyen=("salaire","mean"))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2382498/139432241.py in <module>
# ----> 1 df.groupby("genre").agg(salaire_moyen=("salaire","mean"))
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# -> 1329             grouper, exclusions, obj = get_grouper(
#    1330                 obj,
#    1331                 keys,
#
# ...
